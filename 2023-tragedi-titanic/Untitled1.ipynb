# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
test_df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#     ID  pclass  survived     sex   age  sibsp  parch     fare cabin embarked  \
# 0  401       3         0    male   NaN      0      0   8.0500   NaN        S
# 1  402       3         1  female  22.0      1      0  13.9000   NaN        S
# 2  403       3         0    male   NaN      0      0   7.3125   NaN        S
# 3  404       3         0    male  28.0      2      0   7.9250   NaN        S
# 4  405       3         0    male   NaN      0      0   6.8583   NaN        Q
#
#   boat  body                            home.dest
# 0  NaN   NaN                                  NaN
# 1   16   NaN                       West Haven, CT
# 2  NaN   NaN                                  NaN
# 3  NaN   NaN  Ruotsinphytaa, Finland New York, NY
# 4  NaN   NaN                                  NaN

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin        699
# embarked       2
# boat         583
# body         820
# home.dest    393
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# ID             0
# pclass         0
# sex            0
# age           71
# sibsp          0
# parch          0
# fare           0
# cabin        315
# embarked       0
# boat         240
# body         368
# home.dest    171
# dtype: int64

# %%
df.shape
# Out:
# (909, 13)

# %%
def count(plot):
    plt.figure(figsize=(10,5))
    sns.countplot(x=plot,hue=df['survived'],data=df)
    plt.show()
    return count

# %%
df['cabin'].unique()
# Out:
# array([nan, 'E101', 'B58 B60', 'D20', 'F33', 'E60', 'D45', 'C124', 'F',
#        'C30', 'E68', 'D', 'C32', 'F4', 'F G73', 'B11', 'D30', 'E25',
#        'C105', 'C70', 'B19', 'B39', 'D22', 'C93', 'F E57', 'C111', 'C106',
#        'B51 B53 B55', 'D48', 'D35', 'C22 C26', 'C125', 'C23 C25 C27',
#        'C104', 'C116', 'D50', 'F G63', 'C52', 'A16', 'C62 C64', 'E34',
#        'A10', 'G6', 'B86', 'B36', 'D6', 'A34', 'B101', 'E50', 'C54',
#        'B71', 'B96 B98', 'B69', 'C95', 'C132', 'B22', 'B73', 'C83',
#        'D10 D12', 'C51', 'B61', 'F E69', 'C89', 'C85', 'B102', 'D38',
#        'B57 B59 B63 B66', 'A32', 'E40', 'C118', 'E77', 'A6', 'E49', 'E8',
#        'B77', 'E10', 'E33', 'A20', 'B49', 'E24', 'C101', 'C68', 'C86',
#        'C46', 'C91', 'A36', 'D36', 'B50', 'C28', 'E31', 'E121', 'C99',
#        'D46', 'E38', 'D43', 'C92', 'E58', 'D40', 'A31', 'C31', 'B41',
#        'C65', 'D15', 'C2', 'F E46', 'D47', 'C128', 'C53', 'D56', 'C130',
# ...

# %%
check_cabin = df[(df['survived'] == 1) & (df['cabin'].isin([0, 1]))]

# %%
print(check_cabin)
# Out:
# Empty DataFrame
# Columns: [ID, pclass, survived, sex, age, sibsp, parch, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
import pandas as pd
import numpy as np


survived_data = df[df['survived'] == 1]

# Get unique 'cabin' values where 'survived' is 1
cabin_values_survived_1 = survived_data['cabin'].unique()

# Count the number of NaN values in 'cabin' where 'survived' is 1
nan_count = df[(df['survived'] == 1) & (df['cabin'].isna())].shape[0]

# Fill NaN values in 'cabin' with random values from 'cabin_values_survived_1'
df.loc[(df['survived'] == 1) & (df['cabin'].isna()), 'cabin'] = np.random.choice(cabin_values_survived_1, nan_count, replace=True)

# Display the modified DataFrame
# print(df)

# %%
survived_df = df[df['survived'] == 1]
cabin_values_survived_0=survived_df['cabin'].unique()
nan_count = df[(df['survived'] == 0) & (df['cabin'].isna())].shape[0]
df.loc[(df['survived'] == 0 ) & (df['cabin'].isna()), 'cabin'] = np.random.choice(cabin_values_survived_0, nan_count,replace=True)

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat         583
# body         820
# home.dest    393
# dtype: int64

# %%
df['boat'].unique()
# Out:
# array([nan, '16', '10', '13', 'B', '6', '14', 'C', '4', '11', '15', '3',
#        '8', '7', '5', '9', 'A', 'D', '12', '1', '2', '8 10', '13 15 B',
#        '15 16'], dtype=object)

# %%
import pandas as pd
import numpy as np


survived_data = df[df['survived'] == 1]


boat_values_survived_1 = survived_data['boat'].unique()


nan_count = df[(df['survived'] == 1) & (df['boat'].isna())].shape[0]


df.loc[(df['survived'] == 1) & (df['boat'].isna()), 'boat'] = np.random.choice(boat_values_survived_1, nan_count, replace=True)

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat         562
# body         820
# home.dest    393
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# ID             0
# pclass         0
# sex            0
# age           71
# sibsp          0
# parch          0
# fare           0
# cabin        315
# embarked       0
# boat         240
# body         368
# home.dest    171
# dtype: int64

# %%
import pandas as pd
import numpy as np


survived_data = df[df['survived'] == 0]


boat_values_survived_0 = survived_data['boat'].unique()


nan_count = df[(df['survived'] == 0) & (df['boat'].isna())].shape[0]


df.loc[(df['survived'] == 0) & (df['boat'].isna()), 'boat'] = np.random.choice(boat_values_survived_0, nan_count, replace=True)

# %%
import numpy as np

sex_data = test_df[test_df['sex'] == 'male']
age_value_sex_male = test_df['age'].unique()
nan_count_male = test_df[(test_df['sex'] == 'male') & (test_df['age'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'male') & (test_df['age'].isna()), 'age'] = np.random.choice(age_value_sex_male, nan_count_male, replace=True)

# %%
import numpy as np

sex_data = test_df[test_df['sex'] == 'female']
age_value_sex_female = test_df['age'].unique()
nan_count_female = test_df[(test_df['sex'] == 'female') & (test_df['age'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'female') & (test_df['age'].isna()), 'age'] = np.random.choice(age_value_sex_female, nan_count_female, replace=True)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'male']
age_value_cabin_male = test_df['cabin'].unique()
nan_count_male = test_df[(test_df['sex'] == 'male') & (test_df['cabin'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'male') & (test_df['cabin'].isna()), 'cabin'] = np.random.choice(age_value_cabin_male, nan_count_male, replace=True)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'female']
age_value_cabin_female = test_df['cabin'].unique()
nan_count_female = test_df[(test_df['sex'] == 'female') & (test_df['cabin'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'female') & (test_df['cabin'].isna()), 'cabin'] = np.random.choice(age_value_cabin_female, nan_count_female, replace=True)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'male']
age_value_boat_male = test_df['boat'].unique()
nan_count_male = test_df[(test_df['sex'] == 'male') & (test_df['boat'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'male') & (test_df['boat'].isna()), 'boat'] = np.random.choice(age_value_boat_male, nan_count_male, replace=True)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'female']
age_value_boat_female = test_df['boat'].unique()
nan_count_female = test_df[(test_df['sex'] == 'female') & (test_df['boat'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'female') & (test_df['boat'].isna()), 'boat'] = np.random.choice(age_value_boat_female, nan_count_female, replace=True)

# %%
import pandas as pd
import re


test_df['home.dest'] = test_df['home.dest'].apply(lambda x: ' '.join(re.findall(r'\b\w+\b', str(x))[:1]))

# Display the modified DataFrame
print(test_df['home.dest'].unique())
# Out:
# ['New' 'nan' 'Russia' 'Bournemouth' 'Windsor' 'Philadelphia' 'Cambridge'
#  'Ottawa' 'Syria' 'Paris' 'St' 'Boston' 'Liverpool' 'Youngstown' 'London'
#  'Cornwall' 'Mamaroneck' 'Wiltshire' 'Yoevil' 'Pomeroy' 'Ireland' 'Barre'
#  'Bristol' 'Co' 'England' 'Somerset' 'Amenia' 'Washington' 'Brunswick'
#  'Ilford' 'Tokyo' 'Guernsey' 'Skara' 'Sweden' 'Devonport' 'Roachdale'
#  'Haverford' 'Altdorf' 'Halesworth' 'Norrlot' 'Newark' 'Milwaukee' 'East'
#  'Bournmouth' 'Strood' 'Greece' 'Hudson' 'Croatia' 'Harrow' 'Austria'
#  'Calgary' 'Trenton' 'Halifax' 'Lexington' 'Greenwich' 'Worcester'
#  'Pondersend' 'Cape' 'Rochester' 'Belfast' 'Streatham' 'Plymouth'
#  'Clevedon' 'Bromsgrove' 'Illinois' 'Deer' 'Minneapolis' 'Stockholm'
#  'Portugal' 'Stoughton' 'Seattle' 'Bulgaria' 'Elkins' 'Hartford'
#  'Gallipolis' 'Hamilton' 'Treherbert' 'Glasgow' 'West' 'Chicago'
#  'Rotherfield' 'Nice' 'Denmark' 'Isleworth' 'Guntur' 'Duluth' 'Goteborg'
# ...

# %%
df['home.dest'] = df['home.dest'].replace('nan',np.nan)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'female']
age_value_home_female = test_df['home.dest'].unique()
nan_count_female = test_df[(test_df['sex'] == 'female') & (test_df['home.dest'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'female') & (test_df['home.dest'].isna()), 'home.dest'] = np.random.choice(age_value_home_female, nan_count_female, replace=True)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'male']
age_value_home_male = test_df['home.dest'].unique()
nan_count_male = test_df[(test_df['sex'] == 'male') & (test_df['home.dest'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'male') & (test_df['home.dest'].isna()), 'home.dest'] = np.random.choice(age_value_home_male, nan_count_male, replace=True)

# %%
# Assuming 'test_df' is your DataFrame containing the dataset
# Replace 'your_dataset.csv' with the actual file name or provide the DataFrame in some other way

# Import necessary libraries
import pandas as pd

# Load your dataset
# test_df = pd.read_csv('your_dataset.csv')

# Calculate the maximum and minimum values of 'home.dest' column
max_value = test_df['home.dest'].idxmax()
min_value = test_df['home.dest'].idxmin()

# Calculate the number of NaN values in 'home.dest'
nan_count = test_df['home.dest'].isna().sum()

# Calculate the fill values
fill_values = [max_value] * int(nan_count / 2) + [min_value] * int(nan_count / 2)

# Fill NaN values with calculated fill values
test_df['home.dest'].fillna(value=pd.Series(fill_values), inplace=True)

# Display the modified DataFrame
# print(test_df['home.dest'].unique())

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'male']
age_value_body_male = test_df['body'].unique()
nan_count_male = test_df[(test_df['sex'] == 'male') & (test_df['body'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'male') & (test_df['body'].isna()), 'body'] = np.random.choice(age_value_body_male, nan_count_male, replace=True)

# %%
import numpy as np

cabin_data = test_df[test_df['sex'] == 'female']
age_value_body_female = test_df['body'].unique()
nan_count_female = test_df[(test_df['sex'] == 'female') & (test_df['body'].isna())].shape[0]
test_df.loc[(test_df['sex'] == 'female') & (test_df['body'].isna()), 'body'] = np.random.choice(age_value_body_female, nan_count_female, replace=True)

# %%
test_df['age'] = test_df['age'].fillna(test_df['age'].median())
test_df['cabin'] = test_df['cabin'].fillna(test_df['cabin'].mode()[0])
test_df['boat'] = test_df['boat'].fillna(test_df['boat'].mode()[0])
test_df['body'] = test_df['body'].fillna(test_df['body'].mode()[0])

# %%
test_df['boat'] = test_df['boat'].replace('1',1)
test_df['boat'] = test_df['boat'].replace('2',2)
test_df['boat'] = test_df['boat'].replace('3',3)
test_df['boat'] = test_df['boat'].replace('4',4)
test_df['boat'] = test_df['boat'].replace('5',5)
test_df['boat'] = test_df['boat'].replace('6',6)
test_df['boat'] = test_df['boat'].replace('7',7)
test_df['boat'] = test_df['boat'].replace('8',8)
test_df['boat'] = test_df['boat'].replace('9',9)
test_df['boat'] = test_df['boat'].replace('10',10)
test_df['boat'] = test_df['boat'].replace('11',11)
test_df['boat'] = test_df['boat'].replace('12',12)
test_df['boat'] = test_df['boat'].replace('13',13)
test_df['boat'] = test_df['boat'].replace('14',14)
test_df['boat'] = test_df['boat'].replace('15',15)
# test_df['boat'] = test_df['boat'].replace('16',16)
test_df['boat'] = test_df['boat'].replace('C D',15)

test_df['boat'] = test_df['boat'].replace('5 7',16)
test_df['boat'] = test_df['boat'].replace('13 15',17)
test_df['boat'] = test_df['boat'].replace('5 9',18)

# %%
# df['boat'] = df['boat'].astype('int')

# %%
test_df['boat'].unique()
# Out:
# array([7, 16, 10, '16', 3, 12, 5, 18, 'C', 'A', 8, 11, 15, 13, 14, 9, 4,
#        17, 'D', 6, 'B', 2], dtype=object)

# %%
test_df.isnull().sum()
# Out:
# ID           0
# pclass       0
# sex          0
# age          0
# sibsp        0
# parch        0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %%
test_data = test_df.drop(['ID'],axis=1)

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat         141
# body         820
# home.dest    393
# dtype: int64

# %%
df['boat'] = df['boat'].fillna(df['boat'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat           0
# body         820
# home.dest    393
# dtype: int64

# %%
df['body'].unique()
# Out:
# array([ nan, 142., 232.,  75., 166., 294., 196., 309., 245., 187., 165.,
#        119.,  50.,  98., 122., 135., 188.,  46., 124., 299., 103., 305.,
#          9., 173.,  37., 126., 307.,  18.,  69.,  45., 283., 263., 328.,
#        312.,  52., 209.,  17.,  97., 261.,  62.,   7., 147., 271.,  80.,
#         14.,  43., 249., 189.,  51., 255., 172.,  89.,  19., 130., 298.,
#        208., 121., 275., 148., 143., 295., 234., 327., 133.,  15., 131.,
#         72., 175., 181.,  16., 171.,  67., 236., 258., 206., 230., 207.,
#         79., 174.,  68.,  22., 109., 284., 108.,  70., 197., 149., 297.,
#         38., 120.])

# %%
import pandas as pd
import numpy as np

# Assuming 'df' is your DataFrame containing the dataset
# You may need to replace 'your_dataset.csv' with the actual file name or provide the DataFrame in some other way

# Load your dataset
# df = pd.read_csv('your_dataset.csv')

# Filter rows where 'survived' is 1
survived_data = df[df['survived'] == 0]

# Get unique 'cabin' values where 'survived' is 1
body_values_survived_0 = survived_data['body'].unique()

# Count the number of NaN values in 'cabin' where 'survived' is 1
nan_count = df[(df['survived'] == 0) & (df['body'].isna())].shape[0]

# Fill NaN values in 'cabin' with random values from 'cabin_values_survived_1'
df.loc[(df['survived'] == 0) & (df['body'].isna()), 'body'] = np.random.choice(body_values_survived_0, nan_count, replace=True)

# Display the modified DataFrame
# print(df)

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat           0
# body         347
# home.dest    393
# dtype: int64

# %%
import pandas as pd
import numpy as np



survived_data = df[df['survived'] == 1]


body_values_survived_1 = survived_data['body'].unique()


nan_count = df[(df['survived'] == 1) & (df['body'].isna())].shape[0]


df.loc[(df['survived'] == 1) & (df['body'].isna()), 'body'] = np.random.choice(body_values_survived_1, nan_count, replace=True)

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat           0
# body         347
# home.dest    393
# dtype: int64

# %%
df['body'] = df['body'].fillna(df['body'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat           0
# body           0
# home.dest    393
# dtype: int64

# %%
df['home.dest'].unique()
# Out:
# array([nan, 'West Haven, CT', 'Ruotsinphytaa, Finland New York, NY',
#        'Rotherfield, Sussex, England Essex Co, MA', 'Harrisburg, PA',
#        'Sweden  Worcester, MA', 'Belfast', 'Ireland', 'Bridgerule, Devon',
#        'Cornwall / Akron, OH', 'Montreal, PQ',
#        'Bristol, England / New Britain, CT',
#        'St Ives, Cornwall / Hancock, MI', 'Myren, Sweden New York, NY',
#        'St Austall, Cornwall', 'Haverford, PA', 'London / Montreal, PQ',
#        'Australia Fingal, ND', 'Auburn, NY', 'London', 'Kingston, Surrey',
#        'Surbiton Hill, Surrey', 'England', 'Paris', 'New York, NY',
#        'Pennsylvania', 'Cornwall / Houghton, MI',
#        'New York, NY / Washington, DC', 'Ireland Chicago, IL',
#        'Co Longford, Ireland New York, NY', 'North Evington, England',
#        'Ascot, Berkshire / Rochester, NY',
#        'Guntur, India / Benton Harbour, MI', 'Sweden Akeley, MN',
#        'London / Middlesex', 'Devon, England Wichita, KS',
# ...

# %%
import pandas as pd
import re


df['home.dest'] = df['home.dest'].apply(lambda x: ' '.join(re.findall(r'\b\w+\b', str(x))[:1]))

# Display the modified DataFrame
print(df['home.dest'].unique())
# Out:
# ['nan' 'West' 'Ruotsinphytaa' 'Rotherfield' 'Harrisburg' 'Sweden'
#  'Belfast' 'Ireland' 'Bridgerule' 'Cornwall' 'Montreal' 'Bristol' 'St'
#  'Myren' 'Haverford' 'London' 'Australia' 'Auburn' 'Kingston' 'Surbiton'
#  'England' 'Paris' 'New' 'Pennsylvania' 'Co' 'North' 'Ascot' 'Guntur'
#  'Devon' 'Syria' 'Provo' 'Brooklyn' 'Somerset' 'Kilmacowen' 'Hornsey'
#  'Zurich' 'Bournmouth' 'Washington' 'Krakoryd' 'Frankfort' 'Stockholm'
#  'Barcelona' 'Russia' 'Milford' 'East' 'Sarnia' 'Montevideo' 'Greece'
#  'Cape' 'Austria' 'Finland' 'Southampton' 'Wiltshire' 'Woodford'
#  'Brockton' 'Denmark' 'Germantown' 'Lexington' 'Philadelphia' 'Bulgaria'
#  'Hong' 'Tranvik' 'Greenwich' 'Duluth' 'Winnipeg' 'Toronto' 'Newark'
#  'Bournemouth' 'Haddenfield' 'Perkins' 'Chicago' 'Taalintehdas' 'Bryn'
#  'Liverpool' 'Tuxedo' 'Manchester' 'Krakudden' 'Providence' 'Bath'
#  'Effington' 'Springfield' 'San' 'Buenos' 'Mt' 'Elmira' 'Kingwilliamstown'
# ...

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat           0
# body           0
# home.dest      0
# dtype: int64

# %%
df['home.dest'] = df['home.dest'].replace('nan',np.nan)

# %%
df.shape
# Out:
# (909, 13)

# %%
df.isnull().sum()
# Out:
# ID             0
# pclass         0
# survived       0
# sex            0
# age          192
# sibsp          0
# parch          0
# fare           1
# cabin         10
# embarked       2
# boat           0
# body           0
# home.dest    393
# dtype: int64

# %%
survived_data = df[df['survived'] == 1]
home_values_survived_1 = survived_data['home.dest'].unique()
nan_count = df[(df['survived']==1) & (df['home.dest'].isna())].shape[0]
df.loc[(df['survived'] == 1) & (df['home.dest'].isna()),'home.dest'] = np.random.choice(home_values_survived_1,nan_count,replace=True)

# %%
survived_data = df[df['survived'] == 0]
home_values_survived_0 = survived_data['home.dest'].unique()
nan_count = df[(df['survived'] == 0) &(df['home.dest'].isna())].shape[0]
df.loc[(df['survived'] == 0) & (df['home.dest'].isna()),'home.dest'] = np.random.choice(home_values_survived_0,nan_count,replace=True)

# %%
survived_data = df[df['survived'] == 1]
age_values_survived_1 = survived_data['age'].unique()
nan_count = df[(df['survived'] == 1) & (df['age'].isna())].shape[0]
df.loc[(df['survived']==1) & (df['age'].isna()),'age'] = np.random.choice(age_values_survived_1,nan_count,replace=True)

# %%
survived_data = df[df['survived'] == 0]
age_values_survived_o = survived_data['age'].unique()
nan_count = df[(df['survived'] == 0) & (df['age'].isna())].shape[0]
df.loc[(df['survived']==0) & (df['age'].isna()),'age'] = np.random.choice(age_values_survived_o,nan_count,replace=True)

# %%
df.isnull().sum()
# Out:
# ID            0
# pclass        0
# survived      0
# sex           0
# age           1
# sibsp         0
# parch         0
# fare          1
# cabin        10
# embarked      2
# boat          0
# body          0
# home.dest     2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID           0
# pclass       0
# survived     0
# sex          0
# age          0
# sibsp        0
# parch        0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %%
df.dtypes
# Out:
# ID             int64
# pclass         int64
# survived       int64
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df.describe()
# Out:
#                 ID      pclass   survived         age       sibsp       parch  \
# count   893.000000  893.000000  893.00000  893.000000  893.000000  893.000000
# mean    854.483763    2.292273    0.37514   30.517357    0.481523    0.340426
# std     262.237999    0.839547    0.48443   15.331923    1.067742    0.755036
# min     401.000000    1.000000    0.00000    0.166700    0.000000    0.000000
# 25%     628.000000    2.000000    0.00000   21.000000    0.000000    0.000000
# 50%     855.000000    3.000000    0.00000   29.000000    0.000000    0.000000
# 75%    1081.000000    3.000000    1.00000   40.000000    1.000000    0.000000
# max    1309.000000    3.000000    1.00000   80.000000    8.000000    6.000000
#
#              fare        body
# count  893.000000  893.000000
# mean    32.953708  175.613662
# std     53.591888   76.301368
# min      0.000000    7.000000
# 25%      7.895800  126.000000
# 50%     13.862500  196.000000
# 75%     30.695800  196.000000
# ...

# %%
df.head()
# Out:
#     ID  pclass  survived     sex   age  sibsp  parch     fare  \
# 0  401       3         0    male  28.0      0      0   8.0500
# 1  402       3         1  female  22.0      1      0  13.9000
# 2  403       3         0    male  30.0      0      0   7.3125
# 3  404       3         0    male  28.0      2      0   7.9250
# 4  405       3         0    male  48.0      0      0   6.8583
#
#              cabin embarked boat   body      home.dest
# 0              C31        S    B   22.0        Altdorf
# 1             C105        S   16  196.0           West
# 2              E36        S    A  126.0    Rotherfield
# 3              C32        S    A  149.0  Ruotsinphytaa
# 4  B57 B59 B63 B66        Q    B   80.0          Myren

# %%
df['boat'].unique()
# Out:
# array(['B', '16', 'A', '14', '10', '13', '6', 'C', '4', '11', '15', '3',
#        '8', '7', '5', '9', 'D', '12', '1', '2', '8 10', '13 15 B',
#        '15 16'], dtype=object)

# %%
df['boat'] = df['boat'].replace('A',16)
df['boat'] = df['boat'].replace('B',17)
df['boat'] = df['boat'].replace('C',18)
df['boat'] = df['boat'].replace('D',19)
df['boat'] = df['boat'].replace('8 10',20)
df['boat'] = df['boat'].replace('13 15 B',21)
df['boat'] = df['boat'].replace('15 16',22)

# %%
df['boat'] = df['boat'].replace('1',1)
df['boat'] = df['boat'].replace('2',2)
df['boat'] = df['boat'].replace('3',3)
df['boat'] = df['boat'].replace('4',4)
df['boat'] = df['boat'].replace('5',5)
df['boat'] = df['boat'].replace('6',6)
df['boat'] = df['boat'].replace('7',7)
df['boat'] = df['boat'].replace('8',8)
df['boat'] = df['boat'].replace('9',9)
df['boat'] = df['boat'].replace('10',10)
df['boat'] = df['boat'].replace('11',11)
df['boat'] = df['boat'].replace('12',12)
df['boat'] = df['boat'].replace('13',13)
df['boat'] = df['boat'].replace('14',14)
df['boat'] = df['boat'].replace('15',15)
df['boat'] = df['boat'].replace('16',16)

# %%
df['boat'] = df['boat'].astype('int')

# %%
df.head()
# Out:
#     ID  pclass  survived     sex   age  sibsp  parch     fare  \
# 0  401       3         0    male  28.0      0      0   8.0500
# 1  402       3         1  female  22.0      1      0  13.9000
# 2  403       3         0    male  30.0      0      0   7.3125
# 3  404       3         0    male  28.0      2      0   7.9250
# 4  405       3         0    male  48.0      0      0   6.8583
#
#              cabin embarked  boat   body      home.dest
# 0              C31        S    17   22.0        Altdorf
# 1             C105        S    16  196.0           West
# 2              E36        S    16  126.0    Rotherfield
# 3              C32        S    16  149.0  Ruotsinphytaa
# 4  B57 B59 B63 B66        Q    17   80.0          Myren

# %%
test_df.head(1)
# Out:
#    ID  pclass     sex   age  sibsp  parch     fare    cabin embarked boat  \
# 0   1       1  female  45.0      0      1  63.3583  D10 D12        C    7
#
#     body home.dest
# 0  304.0       New

# %%
X_ = df.drop(['ID','cabin','home.dest','boat','survived'],axis=1)
Y_ = df['survived']
# test_data1 =

# %%
x = df.drop(['ID','survived'],axis=1)
y = df['survived']
test_data1 = test_df.drop(['ID','cabin','boat','home.dest'],axis=1)

# %%
from sklearn.model_selection import train_test_split
xtrian,xtest,ytrain,ytest = train_test_split(X_,Y_,test_size=.2,random_state=39)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score,precision_score,r2_score
from sklearn.linear_model import RidgeClassifier,LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,BaggingClassifier,AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
xtrian.dtypes
# Out:
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# body        float64
# dtype: object

# %%
xtrian.head(1)
# Out:
#     pclass   sex   age  sibsp  parch  fare embarked  body
# 33       2  male  30.0      0      0  13.0        S  75.0

# %%
test_data1.head(1)
# Out:
#    pclass     sex   age  sibsp  parch     fare embarked   body
# 0       1  female  45.0      0      1  63.3583        C  304.0

# %%
# from sklearn.preprocessing import LabelEncoder
# for column in df.columns:
#     if df[column].dtypes == 'object':
#         df[column] = LabelEncoder().fit_transform(df[column])

# %%
# from sklearn.preprocessing import LabelEncoder
# for column in test_data.columns:
#     if test_data[column].dtypes == 'object':
#         test_data[column] = LabelEncoder().fit_transform(test_data[column])

# %%
xtrian.head(1)
# Out:
#     pclass   sex   age  sibsp  parch  fare embarked  body
# 33       2  male  30.0      0      0  13.0        S  75.0

# %%
X = df.drop(['ID','survived'],axis=1)
Y = df['survived']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=.2,random_state=39)

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6])
],remainder='passthrough')
step2 = XGBClassifier()
pipe11 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe11.fit(xtrian,ytrain)
y_pred11 = pipe11.predict(xtest)
print('r2 score',r2_score(ytest,y_pred11))
print('accuracy score',accuracy_score(ytest,y_pred11))
print('Precision score',precision_score(ytest,y_pred11))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 score 0.9027173913043478
# accuracy score 0.9776536312849162
# Precision score 0.96875
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = XGBClassifier()
pipe1 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe1.fit(xtrian,ytrain)
y_pred = pipe1.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# r2 score 1.0
# accuracy score 1.0
# Precision score 1.0
# ...

# %%
crooss = cross_val_score(pipe11,X_train,Y_train,cv=5)
print(crooss.mean())
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = CatBoostClassifier()
pipe2 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe2.fit(xtrian,ytrain)
y_pred = pipe2.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Learning rate set to 0.008933
# 0:	learn: 0.6751676	total: 7.77ms	remaining: 7.76s
# 1:	learn: 0.6643511	total: 14.1ms	remaining: 7.05s
# 2:	learn: 0.6483758	total: 20.7ms	remaining: 6.88s
# 3:	learn: 0.6380489	total: 28.9ms	remaining: 7.21s
# 4:	learn: 0.6277681	total: 36.1ms	remaining: 7.19s
# 5:	learn: 0.6112062	total: 43.1ms	remaining: 7.15s
# 6:	learn: 0.6012229	total: 50.2ms	remaining: 7.13s
# 7:	learn: 0.5855556	total: 57.6ms	remaining: 7.14s
# 8:	learn: 0.5752973	total: 65.9ms	remaining: 7.26s
# 9:	learn: 0.5589156	total: 73.6ms	remaining: 7.28s
# 10:	learn: 0.5455532	total: 78.6ms	remaining: 7.07s
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = RandomForestClassifier()
pipe3 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe3.fit(xtrian,ytrain)
y_pred = pipe3.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 score 0.8628002043944814
# accuracy score 0.9664804469273743
# Precision score 0.9861111111111112
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = GradientBoostingClassifier()
pipe4 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe4.fit(xtrian,ytrain)
y_pred = pipe4.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 score 0.9542667347981604
# accuracy score 0.9888268156424581
# Precision score 0.9743589743589743
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = AdaBoostClassifier()
pipe5 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe5.fit(xtrian,ytrain)
y_pred = pipe5.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 score 0.9542667347981604
# accuracy score 0.9888268156424581
# Precision score 0.9743589743589743
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = BaggingClassifier()
pipe6 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe6.fit(xtrian,ytrain)
y_pred = pipe6.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# r2 score 0.9314001021972407
# accuracy score 0.9832402234636871
# Precision score 0.974025974025974

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = SVC()
pipe7 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe7.fit(xtrian,ytrain)
y_pred = pipe7.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 score 0.5410256410256411
# accuracy score 0.8938547486033519
# Precision score 0.8709677419354839
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = MultinomialNB()
pipe8 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe8.fit(xtrian,ytrain)
y_pred = pipe8.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# r2 score -0.07473173224322993
# accuracy score 0.7374301675977654
# Precision score 0.9142857142857143
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = GaussianNB()
pipe9 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe9.fit(xtrian,ytrain)
y_pred = pipe9.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# r2 score 0.8628002043944814
# accuracy score 0.9664804469273743
# Precision score 1.0
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[1,6,7,10])
],remainder='passthrough')
step2 = BernoulliNB()
pipe10 = Pipeline([
    ('step1',step1),
    ('scaler',MinMaxScaler()),
    ('step2',step2)
])
pipe10.fit(xtrian,ytrain)
y_pred = pipe10.predict(xtest)
print('r2 score',r2_score(ytest,y_pred))
print('accuracy score',accuracy_score(ytest,y_pred))
print('Precision score',precision_score(ytest,y_pred))
# Out:
# r2 score 0.08533469596320864
# accuracy score 0.776536312849162
# Precision score 0.78125
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores = []
for i in range(100):
    Xtrain,Xtest,Ytrain,Ytest = train_test_split(x,y,test_size=.2,random_state=i)
    pipe7.fit(Xtrain,Ytrain)
    y_pred1 = pipe7.predict(Xtest)
    print(scores.append(accuracy_score(Ytest,y_pred1)))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# None
# None
# ...

# %%
np.argmax(scores)
# Out:
# 39

# %%
cros = cross_val_score(pipe1,x,y,cv=5)
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# ...

# %%
cros.mean()
# Out:
# 0.9843575418994412

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, accuracy_score, precision_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# Assuming you have a list of your pipeline models
models = [pipe1, pipe2, pipe3, pipe4, pipe5, pipe6, pipe7, pipe8, pipe9, pipe10]
model_names = ['XGBoost', 'CatBoost', 'Random Forest', 'Gradient Boosting', 'AdaBoost', 'Bagging', 'SVM', 'Multinomial NB', 'Gaussian NB', 'Bernoulli NB']

# Create empty lists to store evaluation scores
accuracy_scores = []
r2_scores = []
precision_scores = []

# Evaluate each model using cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for model in models:
    accuracy = cross_val_score(model, xtrian, ytrain, scoring='accuracy', cv=cv)
    accuracy_scores.append(np.mean(accuracy))
    
    r2 = cross_val_score(model, xtrian, ytrain, scoring='r2', cv=cv)
    r2_scores.append(np.mean(r2))
    
    precision = cross_val_score(model, xtrian, ytrain, scoring='precision', cv=cv)
    precision_scores.append(np.mean(precision))

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(model_names))

rects1 = ax.bar(index - bar_width, accuracy_scores, bar_width, label='Accuracy')
rects2 = ax.bar(index, r2_scores, bar_width, label='R2 Score')
rects3 = ax.bar(index + bar_width, precision_scores, bar_width, label='Precision')

ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Model Comparison')
ax.set_xticks(index)
ax.set_xticklabels(model_names, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# ...

# %%
import pickle


with open('model.pkl', 'wb') as file:
    pickle.dump(pipe1, file)

# %%
prediction = pipe11.predict(test_data)

# %%
submission_df = pd.DataFrame({
    'ID': test_df['ID'],  # Adjust this line based on the actual identifier column in your test data
    'Survived': prediction
})
submission_df.to_csv("submission.csv",index=False)
